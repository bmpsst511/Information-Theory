# %%
from __future__ import division
import numpy
import math

X = [1, 2, 3]
px = [1/4, 1/2, 1/4]

n = 50
Epsilon = 0.1
Monte_CarloExperiments = 1000

trueMean = 0
for i in range(len(px)):
    trueMean = trueMean + X[i] * px[i]

sampleMeans = [0] * Monte_CarloExperiments

for i in range(Monte_CarloExperiments):
    x = numpy.random.choice(X,n,p=px)
    sampleMeans[i] = numpy.mean(x)

v = []

for t in sampleMeans:
    a = float(t) - trueMean
    if (abs(a) < Epsilon):
        v.append(t)


numberWithinEpsilon = len(v)
probability = numberWithinEpsilon / Monte_CarloExperiments
print(probability)

# n = 100
n = 100
for i in range(Monte_CarloExperiments):
    x = numpy.random.choice(X,n,p=px)
    sampleMeans[i] = numpy.mean(x)

v = []

for t in sampleMeans:
    a = float(t) - trueMean
    if (abs(a) < epsilon):
        v.append(t)


numberWithinEpsilon = len(v)
probability = numberWithinEpsilon / Monte_CarloExperiments
print(probability)


#n = 200
n = 200
for i in range(Monte_CarloExperiments):
    x = numpy.random.choice(X,n,p=px)
    sampleMeans[i] = numpy.mean(x)

v = []

for t in sampleMeans:
    a = float(t) - trueMean
    if (abs(a) < Epsilon):
        v.append(t)


numberWithinEpsilon = len(v)
probability = numberWithinEpsilon / Monte_CarloExperiments
print(probability)
# Out:
# 0.601
# 0.811
# 0.932
